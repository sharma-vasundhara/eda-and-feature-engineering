# %% [markdown]
# ## Zomato Transaction Dataset - [Link](https://github.com/krishnaik06/5-Days-Live-EDA-and-Feature-Engineering/blob/main/Zomatodataset.zip) - EDA

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# reading the file
df = pd.read_csv('zomato.csv', encoding = 'latin-1')
df.head() # checking the contents of the dataframe
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape # checking the shape, number of rows & columns
# Out:
# (9551, 21)

# %%
df.columns # column names in the dataframe
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info() # to find data types of columns and info about null values present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe() # get statistics like mean, std, etc. for numerical columns in the dataframe
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ### Finding Missing Values

# %%
df.isnull().sum() # checking for missing values
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# finding features (columns) that have missing values
[features for features in df.columns if df[features].isnull().sum() > 1]
# Out:
# ['Cuisines']

# %%
# creating heatmap for missing values in the dataset
plt.rcParams['figure.figsize'] = (12, 6) # setting size of plots to 12 x 6
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %% [markdown]
# As the dataset consists of 9551 rows and 21 columns, 8 missing values in `Cuisines` column is not visible on the heatmap

# %% [markdown]
# ### Merge with Country Code
# #### Merging the dataset with Country Code dataset to get country names

# %%
# reading the file
df_country = pd.read_excel('Country-Code.xlsx')
df_country.head() # checking the contents
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
# merging the transaction dataset with country code dataset (left join)
final_df = pd.merge(df, df_country, on = 'Country Code', how = 'left')
final_df.head(3) # checking the contents of joined dataframe
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
final_df.dtypes # checking column types
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
country_names = final_df.Country.value_counts().index # country names

# %%
country_values = final_df.Country.value_counts().values # count for each country

# %% [markdown]
# ### Plot Pie Chart For Top 4 Countries

# %%
plt.pie(x = country_values[:3], labels = country_names[:3], autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c9aded448>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# 94.39% of the transactions are from India, followed by United States with 4.73%, and United Kingdom with 0.87%

# %% [markdown]
# ### Relationships

# %%
# diving into ratings
# grouping the data on the basis of rating columns
df_rating = final_df.groupby(['Aggregate rating', 
                              'Rating color', 
                              'Rating text']).size().reset_index().rename(columns = {0: 'Rating Count'})
df_rating
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# #### Observations
#
# | Rating    | Rating Color | Rating Text |
# |-----------|--------------|-------------|
# | 4.5 - 4.9 | Dark Green   | Excellent   |
# | 4.0 - 4.4 | Green        | Very Good   |
# | 3.5 - 3.9 | Yellow       | Good        |
# | 2.5 - 3.4 | Orange       | Average     |
# | 0 - 2.4   | Red          | Poor        |

# %%
# plotting bar graph to check frequency of each rating
sns.barplot(data = df_rating, x = 'Aggregate rating', y = 'Rating Count')

# %%
# coloring the bar graph on the basis of Rating Color in the dataframe
sns.barplot(data = df_rating, 
            x = 'Aggregate rating', 
            y = 'Rating Count', 
            hue = 'Rating color',
            palette = ['lightgrey', 'red', 'orange', 'yellow', 'limegreen', 'darkgreen'],
            dodge = False)

# %% [markdown]
# 1. Not rated count is very high
# 2. Maximum number of ratings are between 2.5 and 3.9

# %%
# plotting bar graph to check the frequency of each color in df_rating
sns.countplot(x = 'Rating color', 
              data = df_rating, 
              palette = ['lightgrey', 'red', 'orange', 'yellow', 'limegreen', 'darkgreen'])

# %%
# countries that have given 0 ratigs
final_df[final_df['Aggregate rating'] == 0.0].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# Maximum number of 0.0 ratings are from Indian customers

# %% [markdown]
# **Countries & Currencies**

# %%
# checking countries and currencies
final_df.groupby(['Country', 'Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %% [markdown]
# **Which countries have online delivery?**

# %%
# checking which countries have online delivery available
final_df.groupby(['Country', 'Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %% [markdown]
# Only two counties have online delivery available - India and UAE

# %% [markdown]
# ### Plot Pie Chart For Top 4 Cities

# %%
# checking top 4 cities with maximum transactions
df_cities = final_df[['City']].groupby('City').size().reset_index().rename(columns = {0: 'Count'}).sort_values('Count', ascending = False)
plt.pie(x = df_cities['Count'][:4], labels = df_cities['City'][:4], autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22c9ab6e3c8>,
# ...
#  [Text(-0.6207499702746028, 0.9081131396495042, 'New Delhi'),
#   Text(0.07888824382658387, -1.0971675555656746, 'Gurgaon'),
#   Text(0.8905335390443715, -0.6457166683903298, 'Noida'),
#   Text(1.0945551812130687, -0.10931127700117002, 'Faridabad')],
#  [Text(-0.338590892877056, 0.4953344398088204, '69.09%'),
#   Text(0.043029951178136655, -0.5984550303085497, '14.11%'),
#   Text(0.4857455667514753, -0.35220909184927074, '13.63%'),
#   Text(0.597030098843492, -0.05962433290972909, '3.17%')])

# %% [markdown]
# ### Finding Top 10 Cuisines

# %%
# finding top cuisines
final_df[['Cuisines']].groupby('Cuisines').size().reset_index().rename(columns = {0: 'Count'}).sort_values(by = 'Count', ascending = False).head(10)
# Out:
#                             Cuisines  Count
# 1306                    North Indian    936
# 1329           North Indian, Chinese    511
# 497                          Chinese    354
# 828                        Fast Food    354
# 1514           North Indian, Mughlai    334
# 331                             Cafe    299
# 177                           Bakery    218
# 1520  North Indian, Mughlai, Chinese    197
# 186                 Bakery, Desserts    170
# 1749                     Street Food    149
